# %%
import pandas as pd

data = pd.read_csv("results0_statistical_analysis.csv", skipinitialspace=True, header=0)

# %%
import warnings
warnings.filterwarnings(
    action='ignore', category=UserWarning, message=r"Boolean Series.*"
)

queries = []
for key in data.QUERY.unique():
    bm25 = data[:][data.QUERY == key][data.NAME == "BM25"]["ALPHA-NDCG"].values[0]
    fr = data[:][data.QUERY == key][data.NAME == "FR"]["ALPHA-NDCG"].values[0]
    mmr = data[:][data.QUERY == key][data.NAME == "MMR"]["ALPHA-NDCG"].values[0]
    cl = data[:][data.QUERY == key][data.NAME == "CL"]["ALPHA-NDCG"].values[0]
    queries.append(
        (key,
        {
            "bm25":bm25,
            "fr":fr,
            "mmr":mmr,
            "cl":cl
        }
        )
    )

# for key in data.QUERY.unique():
#     bm25 = data[:][data.QUERY == key][data.NAME == "BM25"]["TREC"].values[0]
#     fr = data[:][data.QUERY == key][data.NAME == "FR"]["TREC"].values[0]
#     mmr = data[:][data.QUERY == key][data.NAME == "MMR"]["TREC"].values[0]
#     cl = data[:][data.QUERY == key][data.NAME == "CL"]["TREC"].values[0]
#     queries.append(
#         (key,
#         {
#             "bm25":bm25,
#             "fr":fr,
#             "mmr":mmr,
#             "cl":cl
#         }
#         )
#     )
    
print(queries)
# Out:
# [(2, {'bm25': 0.8402545525050238, 'fr': 0.8494686526588919, 'mmr': 0.9063746960822509, 'cl': 0.9120854666179664}), (4, {'bm25': 0.7894913893803704, 'fr': 0.7762301874208586, 'mmr': 0.8811234782359473, 'cl': 0.9376509844780012}), (5, {'bm25': 0.7730752104006327, 'fr': 0.7795623285134268, 'mmr': 0.8363140712050795, 'cl': 0.9355874248945808}), (8, {'bm25': 0.8227683905141244, 'fr': 0.7563218917543948, 'mmr': 0.8941825691890858, 'cl': 0.9479429936471376}), (9, {'bm25': 0.7673930373409864, 'fr': 0.8080852652050023, 'mmr': 0.8346883447056934, 'cl': 0.9446496571513076}), (12, {'bm25': 0.8134301504835418, 'fr': 0.8363890651147428, 'mmr': 0.8868546485078603, 'cl': 0.9207907208590006}), (13, {'bm25': 0.829378863223032, 'fr': 0.7924575982371278, 'mmr': 0.8600779946239036, 'cl': 0.9251338342495375}), (17, {'bm25': 0.8026262239016607, 'fr': 0.7798259677150623, 'mmr': 0.8637789646881225, 'cl': 0.9239026021096938}), (18, {'bm25': 0.8428694237683263, 'fr': 0.7896823220638117, 'mmr': 0.8863316116279207, 'cl': 0.9125906592655878}), (21, {'bm25': 0.8235383441797854, 'fr': 0.817962503891034, 'mmr': 0.8981510852724163, 'cl': 0.9438541475516506}), (28, {'bm25': 0.6847742866286884, 'fr': 0.812941980295031, 'mmr': 0.7924624847912652, 'cl': 0.937222801329142}), (29, {'bm25': 0.816547338550076, 'fr': 0.8238141016082372, 'mmr': 0.9108521296378266, 'cl': 0.927230933667783}), (31, {'bm25': 0.618855182632179, 'fr': 0.645967272173019, 'mmr': 0.7620545130326618, 'cl': 0.9143931698726978}), (37, {'bm25': 0.7681301267557801, 'fr': 0.8388731875770356, 'mmr': 0.843422984350157, 'cl': 0.942133967009304}), (38, {'bm25': 0.6719289364112261, 'fr': 0.7698828789472489, 'mmr': 0.791337781495164, 'cl': 0.8979653816894814}), (39, {'bm25': 0.7848661774121012, 'fr': 0.7695455983673158, 'mmr': 0.8718825001300144, 'cl': 0.9083513863314449}), (40, {'bm25': 0.706102202903405, 'fr': 0.7567419687377303, 'mmr': 0.8009087588293087, 'cl': 0.913203835838981}), (41, {'bm25': 0.7560785896022766, 'fr': 0.8057139900858458, 'mmr': 0.8363063991380103, 'cl': 0.8946542094976137}), (42, {'bm25': 0.8509443054368135, 'fr': 0.8502614448717102, 'mmr': 0.9069812107699284, 'cl': 0.9282214651990104}), (43, {'bm25': 0.783847675374076, 'fr': 0.7980102572564844, 'mmr': 0.9450341107296902, 'cl': 0.9192837053865534})]

# %%
# Importing library 
import scipy.stats as stats 


# sample data
pre = [30, 31, 34, 40, 36, 35, 
       34, 30, 28, 29] 
  
post = [30, 31, 32, 38, 32, 31, 
        32, 29, 28, 30] 
  
# Performing the paired sample t-test 
print(stats.ttest_rel(pre, post))
# Out:
# TtestResult(statistic=2.584921310565987, pvalue=0.029457853822895275, df=9)

# %%
import numpy as np

# %%
bm25 = [x["bm25"] for q,x in queries]
fr = [x["fr"] for q,x in queries]
mmr = [x["mmr"] for q,x in queries]
cl = [x["cl"] if not np.isnan(x["cl"]) else 0 for q,x in queries]

print(stats.ttest_rel(bm25, mmr))  
print(stats.ttest_rel(fr, mmr)) 
print(stats.ttest_rel(cl, mmr))
# Out:
# TtestResult(statistic=-10.866663627842302, pvalue=1.3575336094359134e-09, df=19)
# TtestResult(statistic=-13.107255428033238, pvalue=5.7547954530515956e-11, df=19)
# TtestResult(statistic=6.061290683203002, pvalue=7.885664347253687e-06, df=19)

# %%
print(bm25)
print(fr)
print(mmr)
print(cl)
# Out:
# [0.50531095512919, 0.5109492345773011, 0.310844621955611, 0.2001068280012509, 0.0881566357273915, 0.0262703865852028, 0.2868286213823933, 0.1686435943703564, 0.926777799155426, 0.2844521362170816, 0.1703799504834396, 0.4140293986070515, 0.5526926033623448, 0.4263105171304177, 0.6359194824945589, 0.4747690119230918, 0.3672369052313889, 0.3660584362525443, 0.5456990037434161, 0.4707972303449533]
# [0.3333836726318447, 0.3333836726318447, 0.3333836726318447, 0.3333836726318447, 0.3333836726318447, 0.3333836726318447, 0.3333836726318447, 0.3333836726318447, 0.3333836726318447, 0.3333836726318447, 0.3333836726318447, 0.3333836726318447, 0.3333836726318447, 0.3333836726318447, 0.3333836726318447, 0.3333836726318447, 0.3333836726318447, 0.3333836726318447, 0.3333836726318447, 0.3333836726318447]
# [0.8089408676744718, 0.5088316532880016, 0.5032758593143384, 0.1679842156157993, 0.2165509472135634, 0.0384684070549812, 0.4863776322081984, 0.2728825963550055, 0.9119877999561428, 0.3833260357246106, 0.278806959701513, 0.695738024366932, 0.522740709796614, 0.4568437575432199, 0.5931230235728926, 0.4632595737213542, 0.3864949874758026, 0.5648970397199348, 0.5755414510369147, 0.7348161417960218]
# [0.4767994758293457, 0.3916125663566123, 0.2267935823859174, 0.1290353845597138, 0.1410351133391395, 0.0211768317934535, 0.2491791162490861, 0.1322005960244402, 0.8891019283150448, 0.2618283516763946, 0.16954550972367, 0.5979893856869499, 0.4037170755574302, 0.3770081340200768, 0.5599353582275612, 0.5816598156803381, 0.3206900679837668, 0, 0.5077675919467762, 0.535648052569782]
